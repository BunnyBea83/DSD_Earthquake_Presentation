# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
""" 
dropna() gets rid of 90% of the rows, same with eq_data below
"""

eq_95_23 = pd.read_csv("data/earthquake_1995-2023.csv")
display(eq_95_23[:51])
display(eq_95_23[51:100])
display(eq_95_23[100:150])
display(eq_95_23[150:200])
display(eq_95_23[200:250])
# Out:
#                                                 title  magnitude  \
# 0                    M 6.5 - 42 km W of Sola, Vanuatu        6.5
# 1            M 6.5 - 43 km S of Intipucá, El Salvador        6.5
# 2            M 6.6 - 25 km ESE of Loncopué, Argentina        6.6
# 3               M 7.2 - 98 km S of Sand Point, Alaska        7.2
# 4                            M 7.3 - Alaska Peninsula        7.3
# 5   M 6.6 - 277 km NNE of Codrington, Antigua and ...        6.6
# 6                                       M 6.9 - Tonga        6.9
# 7                   M 7.2 - south of the Fiji Islands        7.2
# 8               M 6.6 - Panama-Colombia border region        6.6
# 9            M 7.1 - southeast of the Loyalty Islands        7.1
# 10           M 7.7 - southeast of the Loyalty Islands        7.7
# 11                 M 7.6 - 95 km WNW of Hihifo, Tonga        7.6
# 12                  M 6.6 - south of the Fiji Islands        6.6
# ...

# %%
eq_data = pd.read_csv("data/earthquake_data.csv")
eq_data
# Out:
#                                             title  magnitude  \
# 0    M 7.0 - 18 km SW of Malango, Solomon Islands        7.0
# 8          M 6.8 - 55 km SSW of Aguililla, Mexico        6.8
# 9          M 7.6 - 35 km SSW of Aguililla, Mexico        7.6
# 10              M 6.9 - 90 km E of Yujing, Taiwan        6.9
# 11               M 6.5 - 96 km SE of Lugu, Taiwan        6.5
# ..                                            ...        ...
# 406      M 6.6 - 183 km SW of Belaya Gora, Russia        6.6
# 408      M 6.9 - 2 km NNE of Yacuanquer, Colombia        6.9
# 415           M 6.9 - 18 km SSW of Obihiro, Japan        6.9
# 416            M 6.8 - 54 km N of Vallenar, Chile        6.8
# 507            M 7.2 - 12km SW of Delta, B.C., MX        7.2
#
#             date_time  cdi  mmi   alert  tsunami   sig net  nst    dmin  \
# 0    22-11-2022 02:03    8    7   green        1   768  us  117  0.5090
# 8    22-09-2022 06:16    8    7  yellow        1  1179  us  175  2.1370
# ...
